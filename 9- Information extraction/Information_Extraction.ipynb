# %% [markdown]
# # Relation Extraction

# %% [markdown]
# ### Syntactic Dependency Structure
# We need the "benepar" python package for this practice.
# Please install this package using `pip install benepar`
#
# The **Dependent tag** represent the grammatical relationships between words in a sentence.
# Here's a breif list of the tags:
#
# | Term         | Description                                                                                        |
# |--------------|----------------------------------------------------------------------------------------------------|
# | **compound** | Represents a compound word, where two or more words are combined to form a single meaning.         |
# | **nsubjpass**| Passive nominal subject. The subject is the receiver of the action (in passive voice).             |
# | **auxpass**  | Passive auxiliary verb, typically forms part of a passive construction (e.g., "was", "is").        |
# | **ROOT**     | The root of the sentence. The main verb or the main action in the sentence.                        |
# | **prep**     | Prepositional modifier. Links a noun to another word (e.g., "on", "in", "by").                     |
# | **nmod**     | Nominal modifier. Modifies a noun (can be a noun, prepositional phrase, etc.).                     |
# | **punct**    | Punctuation. Marks the presence of punctuation in the text.                                        |
# | **pobj**     | Object of a preposition. The noun or pronoun governed by a preposition.                            |
# | **cc**       | Coordinating conjunction. Connects words, phrases, or clauses (e.g., "and", "but").                |
# | **conj**     | Conjunct. The second element in a conjunction, typically connected by a coordinating conjunction.  |
# | **preconj**  | Preconjunct. A word that appears before a conjunction (e.g., "either" in "either...or").           |
# | **dobj**     | Direct object. The noun or pronoun that directly receives the action of the verb.                  |
# | **nsubj**    | Nominal subject. The subject of the sentence performing the action.                                |
# | **mark**     | Marker. Introduces a subordinate clause (e.g., "that", "if", "because").                           |
# | **ccomp**    | Clausal complement. A clause that serves as the complement or object of a verb.                    |
# | **amod**     | Adjectival modifier. An adjective that modifies a noun.                                            |

# %%
import spacy
from spacy.cli.download import download
download(model="en_core_web_sm")
# Out:
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 5.9 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /home/shahab/Documents/VU/NIT6003/NLP-practice/.venv/lib/python3.10/site-packages (from en-core-web-sm==3.7.1) (3.7.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/shahab/Documents/VU/NIT6003/NLP-practice/.venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/shahab/Documents/VU/NIT6003/NLP-practice/.venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/shahab/Documents/VU/NIT6003/NLP-practice/.venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/shahab/Documents/VU/NIT6003/NLP-practice/.venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/shahab/Documents/VU/NIT6003/NLP-practice/.venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /home/shahab/Documents/VU/NIT6003/NLP-practice/.venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/shahab/Documents/VU/NIT6003/NLP-practice/.venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/shahab/Documents/VU/NIT6003/NLP-practice/.venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/shahab/Documents/VU/NIT6003/NLP-practice/.venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /home/shahab/Documents/VU/NIT6003/NLP-practice/.venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /home/shahab/Documents/VU/NIT6003/NLP-practice/.venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.12.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/shahab/Documents/VU/NIT6003/NLP-practice/.venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/shahab/Documents/VU/NIT6003/NLP-practice/.venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/shahab/Documents/VU/NIT6003/NLP-practice/.venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.8.2)
# Requirement already satisfied: jinja2 in /home/shahab/Documents/VU/NIT6003/NLP-practice/.venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.4)
# Requirement already satisfied: setuptools in /home/shahab/Documents/VU/NIT6003/NLP-practice/.venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (59.6.0)
# Requirement already satisfied: packaging>=20.0 in /home/shahab/Documents/VU/NIT6003/NLP-practice/.venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/shahab/Documents/VU/NIT6003/NLP-practice/.venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /home/shahab/Documents/VU/NIT6003/NLP-practice/.venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /home/shahab/Documents/VU/NIT6003/NLP-practice/.venv/lib/python3.10/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/shahab/Documents/VU/NIT6003/NLP-practice/.venv/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /home/shahab/Documents/VU/NIT6003/NLP-practice/.venv/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/shahab/Documents/VU/NIT6003/NLP-practice/.venv/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/shahab/Documents/VU/NIT6003/NLP-practice/.venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/shahab/Documents/VU/NIT6003/NLP-practice/.venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/shahab/Documents/VU/NIT6003/NLP-practice/.venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/shahab/Documents/VU/NIT6003/NLP-practice/.venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.7.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/shahab/Documents/VU/NIT6003/NLP-practice/.venv/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/shahab/Documents/VU/NIT6003/NLP-practice/.venv/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /home/shahab/Documents/VU/NIT6003/NLP-practice/.venv/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /home/shahab/Documents/VU/NIT6003/NLP-practice/.venv/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /home/shahab/Documents/VU/NIT6003/NLP-practice/.venv/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /home/shahab/Documents/VU/NIT6003/NLP-practice/.venv/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /home/shahab/Documents/VU/NIT6003/NLP-practice/.venv/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/shahab/Documents/VU/NIT6003/NLP-practice/.venv/lib/python3.10/site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /home/shahab/Documents/VU/NIT6003/NLP-practice/.venv/lib/python3.10/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/shahab/Documents/VU/NIT6003/NLP-practice/.venv/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/shahab/Documents/VU/NIT6003/NLP-practice/.venv/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.18.0)
# Requirement already satisfied: wrapt in /home/shahab/Documents/VU/NIT6003/NLP-practice/.venv/lib/python3.10/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /home/shahab/Documents/VU/NIT6003/NLP-practice/.venv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.2)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import pandas as pd
import spacy
import en_core_web_sm
from spacy import displacy # import visualization tool
from IPython.display import display

# load English language model
nlp = en_core_web_sm.load()
# Set up the visualization options
options = {"compact": True, "bg": "#ffffff",
           "color": "black", "font": "Source Sans Pro", "distance": 100}

TEXT_SAMPLE = ["I recall that you have given Naksatra birthday gifts",
               "Ezhil cooks and distributes homemade foods",
               "Victoria University is located in Melbourne, Australia and it has both bachelor and master students"] 

for text in TEXT_SAMPLE:
    
    # Create a dataframe for an easy-to-see output
    df = pd.DataFrame()
    # Import the text and get nlp object
    doc = nlp(text)

    # Here parse the examples  using displacy.render method
    displacy.render(doc, style="dep", options=options)
    
    # Obtain the head and dependents of each word
    for tok in doc:
        new_row = {
            "Word":tok.text,
            "Dependent tag": tok.dep_,
            "Head":tok.head,
            "Dependents":list(tok.children),
            "Left dependents":list(tok.rights),
            "Right dependents":list(tok.lefts)
        }
        df = pd.concat([df, pd.DataFrame([new_row])], ignore_index=True)
    
    # Show table in a readable format
    display(df)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="f0e2a773094e45aeb8367766ce9e016b-0" class="displacy" width="950" height="337.0" direction="ltr" style="max-width: none; height: 337.0px; color: black; background: #ffffff; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">recall</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">you</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">have</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">given</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">Naksatra</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">birthday</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">gifts</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f0e2a773094e45aeb8367766ce9e016b-0-0" stroke-width="2px" d="M62,202.0 62,185.33333333333334 141.0,185.33333333333334 141.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f0e2a773094e45aeb8367766ce9e016b-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,204.0 L58,196.0 66,196.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f0e2a773094e45aeb8367766ce9e016b-0-1" stroke-width="2px" d="M262,202.0 262,152.0 547.0,152.0 547.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f0e2a773094e45aeb8367766ce9e016b-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">mark</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M262,204.0 L258,196.0 266,196.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f0e2a773094e45aeb8367766ce9e016b-0-2" stroke-width="2px" d="M362,202.0 362,168.66666666666666 544.0,168.66666666666666 544.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f0e2a773094e45aeb8367766ce9e016b-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M362,204.0 L358,196.0 366,196.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f0e2a773094e45aeb8367766ce9e016b-0-3" stroke-width="2px" d="M462,202.0 462,185.33333333333334 541.0,185.33333333333334 541.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f0e2a773094e45aeb8367766ce9e016b-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M462,204.0 L458,196.0 466,196.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f0e2a773094e45aeb8367766ce9e016b-0-4" stroke-width="2px" d="M162,202.0 162,135.33333333333331 550.0,135.33333333333331 550.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f0e2a773094e45aeb8367766ce9e016b-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">ccomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M550.0,204.0 L554.0,196.0 546.0,196.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f0e2a773094e45aeb8367766ce9e016b-0-5" stroke-width="2px" d="M662,202.0 662,168.66666666666666 844.0,168.66666666666666 844.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f0e2a773094e45aeb8367766ce9e016b-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M662,204.0 L658,196.0 666,196.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f0e2a773094e45aeb8367766ce9e016b-0-6" stroke-width="2px" d="M762,202.0 762,185.33333333333334 841.0,185.33333333333334 841.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f0e2a773094e45aeb8367766ce9e016b-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M762,204.0 L758,196.0 766,196.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f0e2a773094e45aeb8367766ce9e016b-0-7" stroke-width="2px" d="M562,202.0 562,152.0 847.0,152.0 847.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f0e2a773094e45aeb8367766ce9e016b-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M847.0,204.0 L851.0,196.0 843.0,196.0" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">I recall that you have given
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Naksatra
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  birthday gifts</div></span>
#        Word Dependent tag    Head                Dependents Left dependents  \
# 0         I         nsubj  recall                        []              []
# 1    recall          ROOT  recall                [I, given]         [given]
# 2      that          mark   given                        []              []
# 3       you         nsubj   given                        []              []
# 4      have           aux   given                        []              []
# 5     given         ccomp  recall  [that, you, have, gifts]         [gifts]
# 6  Naksatra      compound   gifts                        []              []
# 7  birthday      compound   gifts                        []              []
# 8     gifts          dobj   given      [Naksatra, birthday]              []
#
#        Right dependents
# 0                    []
# 1                   [I]
# 2                    []
# 3                    []
# 4                    []
# 5     [that, you, have]
# 6                    []
# 7                    []
# 8  [Naksatra, birthday]
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="b86db04c36634d48ba7ec0322e18b747-0" class="displacy" width="650" height="237.0" direction="ltr" style="max-width: none; height: 237.0px; color: black; background: #ffffff; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Ezhil</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">cooks</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">distributes</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">homemade</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">foods</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b86db04c36634d48ba7ec0322e18b747-0-0" stroke-width="2px" d="M62,102.0 62,85.33333333333333 147.0,85.33333333333333 147.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b86db04c36634d48ba7ec0322e18b747-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,104.0 L58,96.0 66,96.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b86db04c36634d48ba7ec0322e18b747-0-1" stroke-width="2px" d="M162,102.0 162,85.33333333333333 247.0,85.33333333333333 247.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b86db04c36634d48ba7ec0322e18b747-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M247.0,104.0 L251.0,96.0 243.0,96.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b86db04c36634d48ba7ec0322e18b747-0-2" stroke-width="2px" d="M162,102.0 162,68.66666666666666 350.0,68.66666666666666 350.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b86db04c36634d48ba7ec0322e18b747-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M350.0,104.0 L354.0,96.0 346.0,96.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b86db04c36634d48ba7ec0322e18b747-0-3" stroke-width="2px" d="M462,102.0 462,85.33333333333333 547.0,85.33333333333333 547.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b86db04c36634d48ba7ec0322e18b747-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M462,104.0 L458,96.0 466,96.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b86db04c36634d48ba7ec0322e18b747-0-4" stroke-width="2px" d="M362,102.0 362,68.66666666666666 550.0,68.66666666666666 550.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b86db04c36634d48ba7ec0322e18b747-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M550.0,104.0 L554.0,96.0 546.0,96.0" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ezhil
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  cooks and distributes homemade foods</div></span>
#           Word Dependent tag         Head                 Dependents  \
# 0        Ezhil      compound        cooks                         []
# 1        cooks          ROOT        cooks  [Ezhil, and, distributes]
# 2          and            cc        cooks                         []
# 3  distributes          conj        cooks                    [foods]
# 4     homemade          amod        foods                         []
# 5        foods          dobj  distributes                 [homemade]
#
#       Left dependents Right dependents
# 0                  []               []
# 1  [and, distributes]          [Ezhil]
# 2                  []               []
# 3             [foods]               []
# 4                  []               []
# 5                  []       [homemade]
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="21192830fbd548c7ab5cb6009f0607f9-0" class="displacy" width="1550" height="387.0" direction="ltr" style="max-width: none; height: 387.0px; color: black; background: #ffffff; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Victoria</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">University</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">located</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">Melbourne,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">Australia</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">it</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">has</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="1050">both</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1050">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">bachelor</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="1350">master</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1350">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">students</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-21192830fbd548c7ab5cb6009f0607f9-0-0" stroke-width="2px" d="M62,252.0 62,235.33333333333334 138.0,235.33333333333334 138.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-21192830fbd548c7ab5cb6009f0607f9-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,254.0 L58,246.0 66,246.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-21192830fbd548c7ab5cb6009f0607f9-0-1" stroke-width="2px" d="M162,252.0 162,218.66666666666666 341.0,218.66666666666666 341.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-21192830fbd548c7ab5cb6009f0607f9-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubjpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M162,254.0 L158,246.0 166,246.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-21192830fbd548c7ab5cb6009f0607f9-0-2" stroke-width="2px" d="M262,252.0 262,235.33333333333334 338.0,235.33333333333334 338.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-21192830fbd548c7ab5cb6009f0607f9-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">auxpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M262,254.0 L258,246.0 266,246.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-21192830fbd548c7ab5cb6009f0607f9-0-3" stroke-width="2px" d="M362,252.0 362,235.33333333333334 438.0,235.33333333333334 438.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-21192830fbd548c7ab5cb6009f0607f9-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M438.0,254.0 L442.0,246.0 434.0,246.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-21192830fbd548c7ab5cb6009f0607f9-0-4" stroke-width="2px" d="M562,252.0 562,235.33333333333334 638.0,235.33333333333334 638.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-21192830fbd548c7ab5cb6009f0607f9-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M562,254.0 L558,246.0 566,246.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-21192830fbd548c7ab5cb6009f0607f9-0-5" stroke-width="2px" d="M462,252.0 462,218.66666666666666 641.0,218.66666666666666 641.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-21192830fbd548c7ab5cb6009f0607f9-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M641.0,254.0 L645.0,246.0 637.0,246.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-21192830fbd548c7ab5cb6009f0607f9-0-6" stroke-width="2px" d="M662,252.0 662,235.33333333333334 738.0,235.33333333333334 738.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; let
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Victoria University
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is located in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Melbourne
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Australia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and it has both bachelor and master students</div></span>
#           Word Dependent tag        Head                 Dependents  \
# 0     Victoria      compound  University                         []
# 1   University     nsubjpass     located                 [Victoria]
# 2           is       auxpass     located                         []
# 3      located          ROOT     located  [University, is, in, has]
# 4           in          prep     located                [Australia]
# 5    Melbourne          nmod   Australia                        [,]
# 6            ,         punct   Melbourne                         []
# 7    Australia          pobj          in       [Melbourne, and, it]
# 8          and            cc   Australia                         []
# 9           it          conj   Australia                         []
# 10         has          conj     located                 [students]
# 11        both       preconj    students                         []
# 12    bachelor          nmod    students              [and, master]
# 13         and            cc    bachelor                         []
# 14      master          conj    bachelor                         []
# 15    students          dobj         has           [both, bachelor]
#
#    Left dependents  Right dependents
# 0               []                []
# 1               []        [Victoria]
# 2               []                []
# 3        [in, has]  [University, is]
# 4      [Australia]                []
# 5              [,]                []
# 6               []                []
# 7        [and, it]       [Melbourne]
# 8               []                []
# 9               []                []
# 10      [students]                []
# 11              []                []
# 12   [and, master]                []
# 13              []                []
# 14              []                []
# 15              []  [both, bachelor]

# %% [markdown]
# Reference:
#     http://datamine.unc.edu/jupyter/notebooks/Text%20Mining%20Modules/(3)%20Information%20Extraction.ipynb
